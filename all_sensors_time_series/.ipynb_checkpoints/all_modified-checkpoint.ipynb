# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.4

# %%
import sys
# Add the path to system, local or mounted S3 bucket, e.g. /dbfs/mnt/<path_to_bucket>
sys.path.append('./secrets.py')

import logging
import math
import os

from influxdb import DataFrameClient
import numpy as np
import matplotlib.mlab as mlab
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate
from tqdm import tqdm
# %matplotlib inline

logging.basicConfig(level=logging.INFO)
LOGGER = logging.getLogger(__name__)

# Need to ssh tunnel for this to work
# ssh -L 8086:localhost:8086 aq.byu.edu -N
influx = DataFrameClient(
    host=HOST,
    port=PORT,
    username=USERNAME,
    password=PASSWORD,
    database=DATABASE,
)


def large_query(influx, measurement, query, total=None, limit=100_000):
    if total is not None:
        total = math.ceil(total / limit)

    with tqdm(total=total) as pbar:
        offset = 0
        while True:
            new_query = query + " LIMIT {} OFFSET {}".format(limit, offset)
            data = influx.query(new_query)
            data = data[measurement]

            received = len(data)
            pbar.update(1)

            yield data

            offset += limit
            if received != limit:
                break


def load_data(filename):
    if os.path.exists(filename):
        LOGGER.info("Loading cached data...")
        return pd.read_hdf(filename)

    LOGGER.info("Downloading data...")
    result = influx.query(
        "SELECT COUNT(sequence) FROM air_quality_sensor WHERE time > '2019-10-01' AND time <= now()"
    )
    count = result["air_quality_sensor"].values[0][0]

    queries = large_query(
        influx,
        "air_quality_sensor",
        "SELECT * FROM air_quality_sensor WHERE time > '2019-10-01' AND time <= now()",
        count,
    )

    all_data = pd.concat(list(queries), sort=False)
    all_data.to_hdf(filename, "data")
    return all_data


data = load_data("aq_data.h5")
gold_data = load_data("aq_data.h5")

LOGGER.info("Done loading data...")
# Out:
# INFO:__main__:Loading cached data...
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:__main__:Loading cached data...
# INFO:__main__:Done loading data...

# %%
# all_modified_gers - This is the working boxplot for all_modified_gers only Mongolia deployed sensors
# https://stackoverflow.com/questions/22800079/converting-time-zone-pandas-dataframe
# https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.between_time.html

from IPython.core.debugger import set_trace 
# https://matplotlib.org/3.1.3/gallery/statistics/boxplot_color.html 
data = gold_data
print(data.index[1])
# data = data.tz_convert(None)
# data.index = data.index.tz_localize('GMT')
data.index = data.index.tz_convert('Asia/Ulaanbaatar')
print(data.index[1])

labels = ['All Modified Gers']
plt.xlabel('')
plt.ylabel('PM 2.5 Value')
plt.title('Week PM 2.5 for All Modified Gers Sensors')
plt.grid(True)
days = ['05', '06', '07', '08', '09', '10', '11']
data = data[data.pm2_5 >= 0]
data = data[data.location_name == 'Mongolia']
modified_gers = ['AL', 'AR', 'AZ', 'CA', 'CT', 'DE', 'IA', 'ID', 'IL', 'KS', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'NH', 'NM', 'GA', 'ND', 'NE']
data = data[(data.name == modified_gers[0]) | (data.name == modified_gers[1]) | (data.name == modified_gers[2]) | (data.name == modified_gers[3]) | (data.name == modified_gers[4]) | (data.name == modified_gers[5]) | (data.name == modified_gers[6]) | (data.name == modified_gers[7]) | (data.name == modified_gers[8]) | (data.name == modified_gers[9]) | (data.name == modified_gers[10]) | (data.name == modified_gers[11]) | (data.name == modified_gers[12]) | (data.name == modified_gers[13]) | (data.name == modified_gers[14]) | (data.name == modified_gers[15]) | (data.name == modified_gers[16]) | (data.name == modified_gers[17]) | (data.name == modified_gers[18]) | (data.name == modified_gers[19]) | (data.name == modified_gers[20]) | (data.name == modified_gers[21]) | (data.name == modified_gers[22]) | (data.name == modified_gers[23])]

# find the gers where the pm2.5 is above 1000
above_one_hundred_gers = data[data.pm2_5 >= 1000]
above_one_hundred_sensors_names = []
for name, sensor_data in above_one_hundred_gers.groupby("name"):
    above_one_hundred_sensors_names.append(name)
print("All Sensors names above 1000:", above_one_hundred_sensors_names)
print ("how many data points are above 1000: ", len(above_one_hundred_gers))
print ("how many data points overall: ", len(data))
# end of find the gers where the pm2.5 is above 1000

all_sensors_names = []
for name, sensor_data in data.groupby("name"):
    all_sensors_names.append(name)
print("All Sensors names:", all_sensors_names)

day_names = data.index.day_name()
print(type(day_names))
print(day_names[:10])

all_modified_gers = [data['pm2_5']]
print('{} list size: {}'.format(labels[0], len(data['pm2_5'])))
results = plt.boxplot(all_modified_gers, showfliers=False, labels=labels, showmeans=True, meanline=True)

# print(results)
print('whiskers: ', [item.get_ydata()[1] for item in results['whiskers']])
print('caps: ', [item.get_ydata()[1] for item in results['caps']])
print('boxes: ', [item.get_ydata()[1] for item in results['boxes']])
print('medians: ', [item.get_ydata()[1] for item in results['medians']])
print('means: ', [item.get_ydata()[1] for item in results['means']])
print('fliers: ', [item.get_ydata()[1] for item in results['fliers']])

data = gold_data
# Out:
# 2019-11-04 08:00:02+08:00
# 2019-11-04 08:00:02+08:00
# All Sensors names above 1000: ['AL', 'AR', 'AZ', 'CA', 'CT', 'DE', 'GA', 'IA', 'ID', 'IL', 'KS', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NM']
# how many data points are above 1000:  27209
# how many data points overall:  3580523
# All Sensors names: ['AL', 'AR', 'AZ', 'CA', 'CT', 'DE', 'GA', 'IA', 'ID', 'IL', 'KS', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NM']
# <class 'pandas.core.indexes.base.Index'>
# Index(['Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday',
#        'Monday', 'Monday', 'Monday'],
#       dtype='object')
# All Modified Gers list size: 3580523
# whiskers:  [0.0, 355.0]
# caps:  [0.0, 355.0]
# boxes:  [18.0]
# medians:  [48.0]
# means:  [125.85230006901226]
# fliers:  []

# %%
# modified_gers - This is the working boxplot for modified_gers only Mongolia deployed sensors
# https://stackoverflow.com/questions/22800079/converting-time-zone-pandas-dataframe
# https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.between_time.html

from IPython.core.debugger import set_trace 
# https://matplotlib.org/3.1.3/gallery/statistics/boxplot_color.html 
data = gold_data
print(data.index[1])
# data = data.tz_convert(None)
# data.index = data.index.tz_localize('GMT')
data.index = data.index.tz_convert('Asia/Ulaanbaatar')
print(data.index[1])

labels = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
plt.xlabel('Dates')
plt.ylabel('PM 2.5 Value')
plt.title('Week PM 2.5 for sensors')
plt.grid(True)
days = ['05', '06', '07', '08', '09', '10', '11']
data = data[data.pm2_5 >= 0]
data = data[data.location_name == 'Mongolia']
modified_gers = ['AL', 'AR', 'AZ', 'CA', 'CT', 'DE', 'IA', 'ID', 'IL', 'KS', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'NH', 'NM', 'GA', 'ND', 'NE']
data = data[(data.name == modified_gers[0]) | (data.name == modified_gers[1]) | (data.name == modified_gers[2]) | (data.name == modified_gers[3]) | (data.name == modified_gers[4]) | (data.name == modified_gers[5]) | (data.name == modified_gers[6]) | (data.name == modified_gers[7]) | (data.name == modified_gers[8]) | (data.name == modified_gers[9]) | (data.name == modified_gers[10]) | (data.name == modified_gers[11]) | (data.name == modified_gers[12]) | (data.name == modified_gers[13]) | (data.name == modified_gers[14]) | (data.name == modified_gers[15]) | (data.name == modified_gers[16]) | (data.name == modified_gers[17]) | (data.name == modified_gers[18]) | (data.name == modified_gers[19]) | (data.name == modified_gers[20]) | (data.name == modified_gers[21]) | (data.name == modified_gers[22]) | (data.name == modified_gers[23])]

all_sensors_names = []
for name, sensor_data in data.groupby("name"):
    all_sensors_names.append(name)
print("All Sensors names:", all_sensors_names)

day_names = data.index.day_name()
print(type(day_names))
print(day_names[:10])

monday = data[(data.index.day_name() == 'Monday')]['pm2_5']
tuesday = data[data.index.day_name() == 'Tuesday']['pm2_5']
wednesday = data[data.index.day_name() == 'Wednesday']['pm2_5']
thursday = data[data.index.day_name() == 'Thursday']['pm2_5']
friday = data[data.index.day_name() == 'Friday']['pm2_5']
saturday = data[data.index.day_name() == 'Saturday']['pm2_5']
sunday = data[data.index.day_name() == 'Sunday']['pm2_5']
all_days = [monday, tuesday, wednesday, thursday, friday, saturday, sunday]

results = plt.boxplot(all_days, showfliers=False, labels=labels, showmeans=True, meanline=True)

i = 0
cumulative = 0
for day in all_days:
    print('{} list size: {}'.format(labels[i], len(day)))
    cumulative += len(day)
    i+= 1
print('total for all days: {}'.format(cumulative))
print()

# print(results)
print('whiskers: ', [item.get_ydata()[1] for item in results['whiskers']])
print('caps: ', [item.get_ydata()[1] for item in results['caps']])
print('boxes: ', [item.get_ydata()[1] for item in results['boxes']])
print('medians: ', [item.get_ydata()[1] for item in results['medians']])
print('means: ', [item.get_ydata()[1] for item in results['means']])
print('fliers: ', [item.get_ydata()[1] for item in results['fliers']])

data = gold_data
# Out:
# 2019-11-04 08:00:02+08:00
# 2019-11-04 08:00:02+08:00
# All Sensors names: ['AL', 'AR', 'AZ', 'CA', 'CT', 'DE', 'GA', 'IA', 'ID', 'IL', 'KS', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NM']
# <class 'pandas.core.indexes.base.Index'>
# Index(['Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday',
#        'Monday', 'Monday', 'Monday'],
#       dtype='object')
# Mon list size: 489936
# Tue list size: 503266
# Wed list size: 524898
# Thu list size: 516332
# Fri list size: 527891
# Sat list size: 517072
# Sun list size: 501128
# total for all days: 3580523
#
# whiskers:  [0.0, 327.0, 0.0, 348.0, 0.0, 355.0, 0.0, 357.0, 0.0, 380.0, 0.0, 345.0, 0.0, 377.0]
# caps:  [0.0, 327.0, 0.0, 348.0, 0.0, 355.0, 0.0, 357.0, 0.0, 380.0, 0.0, 345.0, 0.0, 377.0]
# boxes:  [17.0, 16.0, 15.0, 17.0, 20.0, 20.0, 20.0]
# medians:  [45.0, 46.0, 42.0, 48.0, 53.0, 48.0, 55.0]
# means:  [119.88050888279285, 117.58221099776262, 123.47963032817805, 123.15392809277752, 131.19803520044857, 133.63471238048086, 131.6002977283249]
# fliers:  []

# %%
# modified_gers each sensors - This is the working boxplot for modified_gers only Mongolia deployed sensors
# https://stackoverflow.com/questions/22800079/converting-time-zone-pandas-dataframe
# https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.between_time.html
import numpy as np
from IPython.core.debugger import set_trace 
# https://matplotlib.org/3.1.3/gallery/statistics/boxplot_color.html 
data = gold_data
print(data.index[1])
# data = data.tz_convert(None)
# data.index = data.index.tz_localize('GMT')
data.index = data.index.tz_convert('Asia/Ulaanbaatar')
print(data.index[1])

labels = ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DE', 'FL', 'IA', 'KS', 'KY', 'LA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'NH', 'GA', 'ND', 'NE']
plt.xlabel('Sensors')
plt.ylabel('PM 2.5 Value')
plt.title('Week PM 2.5 for sensors')
plt.grid(True)
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
data = data[data.pm2_5 >= 0]
data = data[data.location_name == 'Mongolia']
modified_gers = ['AL', 'AR', 'AZ', 'CA', 'CT', 'DE', 'IA', 'ID', 'IL', 'KS', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'NH', 'NM', 'GA', 'ND', 'NE']
data = data[(data.name == modified_gers[0]) | (data.name == modified_gers[1]) | (data.name == modified_gers[2]) | (data.name == modified_gers[3]) | (data.name == modified_gers[4]) | (data.name == modified_gers[5]) | (data.name == modified_gers[6]) | (data.name == modified_gers[7]) | (data.name == modified_gers[8]) | (data.name == modified_gers[9]) | (data.name == modified_gers[10]) | (data.name == modified_gers[11]) | (data.name == modified_gers[12]) | (data.name == modified_gers[13]) | (data.name == modified_gers[14]) | (data.name == modified_gers[15]) | (data.name == modified_gers[16]) | (data.name == modified_gers[17]) | (data.name == modified_gers[18]) | (data.name == modified_gers[19]) | (data.name == modified_gers[20]) | (data.name == modified_gers[21]) | (data.name == modified_gers[22]) | (data.name == modified_gers[23])]

all_sensors_names = []
for name, sensor_data in data.groupby("name"):
    all_sensors_names.append(name)
print("All Sensors names:", all_sensors_names)

day_names = data.index.day_name()
print(type(day_names))
print(day_names[:10])


# for name, sensor_data in data.groupby("name"):
for day in days_of_week:
    plt.xlabel('Sensors for {0}'.format(day))
    plt.ylabel('PM 2.5 Value')
    plt.title('Week PM 2.5 for sensors for {0}'.format(day))
    plt.grid(True)
    sensors_data = list()
    sensors_name = list()
    temp = data[data.index.day_name() == day]
    # temp = temp.groupby("name")
    cumulative = 0
    for name, sensor_data in temp.groupby("name"):
        sensors_name.append(name)
        sensors_data.append(temp.groupby("name").get_group(name)["pm2_5"].to_numpy().tolist())
        cumulative += len(sensor_data)
        print('{} - {} list size: {}'.format(day, name,  len(sensor_data)))
        print('{} - {} list size of data above 1000: {}'.format(day, name,  len(sensor_data[sensor_data.pm2_5 >= 1000])))
    print ('{} total: {}'.format(day, cumulative))    
    print()
    results = plt.boxplot(sensors_data, showfliers=False, labels=sensors_name, showmeans=True, meanline=True)
    print('whiskers: ', [item.get_ydata()[1] for item in results['whiskers']])
    print('caps: ', [item.get_ydata()[1] for item in results['caps']])
    print('boxes: ', [item.get_ydata()[1] for item in results['boxes']])
    print('medians: ', [item.get_ydata()[1] for item in results['medians']])
    print('means: ', [item.get_ydata()[1] for item in results['means']])
    print('fliers: ', [item.get_ydata()[1] for item in results['fliers']])
    plt.show()
    
data = gold_data
# Out:
# 2019-11-04 08:00:02+08:00
# 2019-11-04 08:00:02+08:00
# All Sensors names: ['AL', 'AR', 'AZ', 'CA', 'CT', 'DE', 'GA', 'IA', 'ID', 'IL', 'KS', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NM']
# <class 'pandas.core.indexes.base.Index'>
# Index(['Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday',
#        'Monday', 'Monday', 'Monday'],
#       dtype='object')
# Monday - AL list size: 27771
# Monday - AL list size of data above 1000: 108
# Monday - AR list size: 16990
# Monday - AR list size of data above 1000: 279
# Monday - AZ list size: 30094
# Monday - AZ list size of data above 1000: 173
# Monday - CA list size: 21565
# Monday - CA list size of data above 1000: 1
# Monday - CT list size: 9791
# Monday - CT list size of data above 1000: 158
# Monday - DE list size: 31237
# Monday - DE list size of data above 1000: 108
# Monday - GA list size: 17136
# Monday - GA list size of data above 1000: 21
# Monday - IA list size: 8621
# Monday - IA list size of data above 1000: 195
# Monday - ID list size: 23148
# Monday - ID list size of data above 1000: 62
# Monday - IL list size: 14637
# Monday - IL list size of data above 1000: 37
# Monday - KS list size: 15602
# Monday - KS list size of data above 1000: 109
# Monday - LA list size: 15439
# Monday - LA list size of data above 1000: 57
# Monday - MA list size: 30226
# Monday - MA list size of data above 1000: 15
# Monday - MD list size: 21135
# Monday - MD list size of data above 1000: 74
# Monday - ME list size: 31638
# Monday - ME list size of data above 1000: 56
# Monday - MI list size: 6423
# Monday - MI list size of data above 1000: 270
# Monday - MN list size: 15106
# Monday - MN list size of data above 1000: 96
# Monday - MS list size: 20014
# Monday - MS list size of data above 1000: 151
# Monday - MT list size: 16792
# Monday - MT list size of data above 1000: 249
# Monday - NC list size: 19129
# Monday - NC list size of data above 1000: 114
# Monday - ND list size: 29682
# Monday - ND list size of data above 1000: 742
# Monday - NE list size: 29916
# Monday - NE list size of data above 1000: 7
# Monday - NH list size: 20015
# Monday - NH list size of data above 1000: 502
# Monday - NM list size: 17829
# Monday - NM list size of data above 1000: 20
# Monday total: 489936
#
# whiskers:  [1.0, 129.0, 71.0, 841.0, 1.0, 212.0, 0.0, 88.0, 3.0, 306.0, 1.0, 146.0, 1.0, 98.0, 1.0, 394.0, 140.0, 271.0, 3.0, 247.0, 1.0, 211.0, 0.0, 100.0, 1.0, 166.0, 0.0, 269.0, 1.0, 274.0, 6.0, 521.0, 1.0, 176.0, 1.0, 211.0, 1.0, 282.0, 0.0, 109.0, 1.0, 141.0, 163.0, 247.0, 1.0, 230.0, 1.0, 131.0]
# caps:  [1.0, 129.0, 71.0, 841.0, 1.0, 212.0, 0.0, 88.0, 3.0, 306.0, 1.0, 146.0, 1.0, 98.0, 1.0, 394.0, 140.0, 271.0, 3.0, 247.0, 1.0, 211.0, 0.0, 100.0, 1.0, 166.0, 0.0, 269.0, 1.0, 274.0, 6.0, 521.0, 1.0, 176.0, 1.0, 211.0, 1.0, 282.0, 0.0, 109.0, 1.0, 141.0, 163.0, 247.0, 1.0, 230.0, 1.0, 131.0]
# boxes:  [12.0, 360.0, 20.0, 11.0, 21.0, 16.0, 13.0, 29.0, 189.0, 22.0, 9.0, 8.0, 14.0, 22.0, 19.0, 66.0, 19.0, 16.0, 25.0, 9.0, 9.0, 177.0, 13.0, 9.0]
# medians:  [27.0, 477.0, 48.0, 21.0, 44.0, 35.0, 27.0, 83.0, 197.0, 50.0, 27.0, 24.0, 34.0, 51.0, 53.0, 128.0, 43.0, 44.0, 57.0, 23.0, 23.0, 186.0, 41.0, 22.0]
# means:  [53.927334269561776, 478.31200706297824, 89.05346580713764, 33.53656387665198, 202.55397814319272, 62.81137753305375, 40.904820261437905, 209.9850365386846, 218.5883877656817, 93.33777413404385, 124.43885399307781, 69.92965865664874, 62.65291470919076, 99.57544357700496, 96.16704595739301, 282.3565312159427, 77.46193565470674, 88.18901768761867, 145.4073963792282, 54.319567149354384, 169.66872178424634, 198.03008423586041, 137.22653010242317, 46.30141903640137]
# fliers:  []
# Tuesday - AL list size: 27834
# Tuesday - AL list size of data above 1000: 117
# Tuesday - AR list size: 17393
# Tuesday - AR list size of data above 1000: 593
# Tuesday - AZ list size: 31940
# Tuesday - AZ list size of data above 1000: 29
# Tuesday - CA list size: 21025
# Tuesday - CA list size of data above 1000: 16
# Tuesday - CT list size: 11891
# Tuesday - CT list size of data above 1000: 134
# Tuesday - DE list size: 32088
# Tuesday - DE list size of data above 1000: 97
# Tuesday - GA list size: 15943
# Tuesday - GA list size of data above 1000: 15
# Tuesday - IA list size: 5286
# Tuesday - IA list size of data above 1000: 135
# Tuesday - ID list size: 23926
# Tuesday - ID list size of data above 1000: 121
# Tuesday - IL list size: 13628
# Tuesday - IL list size of data above 1000: 42
# Tuesday - KS list size: 15855
# Tuesday - KS list size of data above 1000: 295
# Tuesday - LA list size: 13027
# Tuesday - LA list size of data above 1000: 52
# Tuesday - MA list size: 30687
# Tuesday - MA list size of data above 1000: 253
# Tuesday - MD list size: 23087
# Tuesday - MD list size of data above 1000: 101
# Tuesday - ME list size: 32012
# Tuesday - ME list size of data above 1000: 112
# Tuesday - MI list size: 7649
# Tuesday - MI list size of data above 1000: 138
# Tuesday - MN list size: 17717
# Tuesday - MN list size of data above 1000: 221
# Tuesday - MS list size: 20264
# Tuesday - MS list size of data above 1000: 167
# Tuesday - MT list size: 21343
# Tuesday - MT list size of data above 1000: 95
# Tuesday - NC list size: 20363
# Tuesday - NC list size of data above 1000: 2
# Tuesday - ND list size: 30674
# Tuesday - ND list size of data above 1000: 300
# Tuesday - NE list size: 30104
# Tuesday - NE list size of data above 1000: 103
# Tuesday - NH list size: 19439
# Tuesday - NH list size of data above 1000: 372
# Tuesday - NM list size: 20091
# Tuesday - NM list size of data above 1000: 35
# Tuesday total: 503266
#
# whiskers:  [0.0, 162.0, 4.0, 843.0, 0.0, 224.0, 0.0, 96.0, 3.0, 205.0, 0.0, 146.0, 0.0, 89.0, 6.0, 367.0, 120.0, 315.0, 4.0, 361.0, 0.0, 287.0, 0.0, 87.0, 0.0, 181.0, 0.0, 315.0, 0.0, 344.0, 2.0, 326.0, 0.0, 247.0, 0.0, 198.0, 0.0, 272.0, 0.0, 110.0, 0.0, 108.0, 164.0, 273.0, 2.0, 255.0, 0.0, 152.0]
# caps:  [0.0, 162.0, 4.0, 843.0, 0.0, 224.0, 0.0, 96.0, 3.0, 205.0, 0.0, 146.0, 0.0, 89.0, 6.0, 367.0, 120.0, 315.0, 4.0, 361.0, 0.0, 287.0, 0.0, 87.0, 0.0, 181.0, 0.0, 315.0, 0.0, 344.0, 2.0, 326.0, 0.0, 247.0, 0.0, 198.0, 0.0, 272.0, 0.0, 110.0, 0.0, 108.0, 164.0, 273.0, 2.0, 255.0, 0.0, 152.0]
# boxes:  [10.0, 311.0, 17.0, 9.0, 18.0, 16.0, 9.0, 30.0, 190.0, 26.0, 12.0, 7.0, 14.0, 18.0, 19.0, 34.0, 17.0, 16.0, 20.0, 10.0, 8.0, 178.0, 18.0, 10.0]
# medians:  [25.0, 446.0, 45.0, 22.0, 41.0, 33.0, 19.0, 75.0, 201.0, 67.0, 40.0, 17.0, 38.0, 57.0, 48.0, 76.0, 46.0, 41.0, 53.0, 23.0, 22.0, 191.0, 49.0, 25.0]
# means:  [61.444707911187756, 480.514344851377, 76.7749843456481, 38.472152199762185, 101.15288873938273, 62.21453502867116, 38.14100232076773, 282.770525917518, 237.9958204463763, 110.14462870560611, 243.8567013560391, 46.887925078682734, 84.9629158927233, 108.43855849612336, 104.17502811445708, 154.39181592365014, 111.73686290003951, 87.28345834978286, 99.12673944618845, 36.04670235230565, 81.8811045184847, 219.03129152272123, 126.37640825145327, 54.01383704146135]
# fliers:  []
# Wednesday - AL list size: 27843
# Wednesday - AL list size of data above 1000: 99
# Wednesday - AR list size: 20544
# Wednesday - AR list size of data above 1000: 524
# Wednesday - AZ list size: 32154
# Wednesday - AZ list size of data above 1000: 95
# Wednesday - CA list size: 21508
# Wednesday - CA list size of data above 1000: 3
# Wednesday - CT list size: 10396
# Wednesday - CT list size of data above 1000: 113
# Wednesday - DE list size: 33049
# Wednesday - DE list size of data above 1000: 256
# Wednesday - GA list size: 15778
# Wednesday - GA list size of data above 1000: 1
# Wednesday - IA list size: 7296
# Wednesday - IA list size of data above 1000: 230
# Wednesday - ID list size: 26913
# Wednesday - ID list size of data above 1000: 24
# Wednesday - IL list size: 13720
# Wednesday - IL list size of data above 1000: 63
# Wednesday - KS list size: 17139
# Wednesday - KS list size of data above 1000: 240
# Wednesday - LA list size: 11415
# Wednesday - LA list size of data above 1000: 32
# Wednesday - MA list size: 31605
# Wednesday - MA list size of data above 1000: 291
# Wednesday - MD list size: 25181
# Wednesday - MD list size of data above 1000: 52
# Wednesday - ME list size: 33067
# Wednesday - ME list size of data above 1000: 81
# Wednesday - MI list size: 6337
# Wednesday - MI list size of data above 1000: 83
# Wednesday - MN list size: 18076
# Wednesday - MN list size of data above 1000: 98
# Wednesday - MS list size: 23362
# Wednesday - MS list size of data above 1000: 476
# Wednesday - MT list size: 23055
# Wednesday - MT list size of data above 1000: 139
# Wednesday - NC list size: 21624
# Wednesday - NC list size of data above 1000: 52
# Wednesday - ND list size: 32723
# Wednesday - ND list size of data above 1000: 602
# Wednesday - NE list size: 31359
# Wednesday - NE list size of data above 1000: 4
# Wednesday - NH list size: 20235
# Wednesday - NH list size of data above 1000: 375
# Wednesday - NM list size: 20519
# Wednesday - NM list size of data above 1000: 95
# Wednesday total: 524898
#
# whiskers:  [0.0, 122.0, 9.0, 849.0, 0.0, 198.0, 0.0, 114.0, 0.0, 197.0, 0.0, 167.0, 0.0, 81.0, 0.0, 296.0, 170.0, 249.0, 4.0, 338.0, 0.0, 141.0, 0.0, 78.0, 0.0, 175.0, 0.0, 307.0, 0.0, 272.0, 3.0, 252.0, 1.0, 174.0, 0.0, 254.0, 1.0, 263.0, 0.0, 103.0, 0.0, 113.0, 127.0, 255.0, 0.0, 311.0, 0.0, 110.0]
# caps:  [0.0, 122.0, 9.0, 849.0, 0.0, 198.0, 0.0, 114.0, 0.0, 197.0, 0.0, 167.0, 0.0, 81.0, 0.0, 296.0, 170.0, 249.0, 4.0, 338.0, 0.0, 141.0, 0.0, 78.0, 0.0, 175.0, 0.0, 307.0, 0.0, 272.0, 3.0, 252.0, 1.0, 174.0, 0.0, 254.0, 1.0, 263.0, 0.0, 103.0, 0.0, 113.0, 127.0, 255.0, 0.0, 311.0, 0.0, 110.0]
# boxes:  [12.0, 324.0, 18.0, 9.0, 20.0, 12.0, 9.0, 16.0, 189.0, 21.0, 9.0, 6.0, 13.0, 17.0, 17.0, 30.0, 14.0, 15.0, 16.0, 11.0, 7.0, 175.0, 16.0, 10.0]
# medians:  [28.0, 470.0, 39.0, 21.0, 41.0, 28.0, 18.0, 40.0, 196.0, 51.0, 24.0, 12.0, 36.0, 56.0, 46.0, 55.0, 35.0, 39.0, 41.0, 25.0, 20.0, 185.0, 52.0, 21.0]
# means:  [54.61347555938656, 485.9496203271028, 107.77477141257697, 38.164775897340526, 100.05588687956906, 73.5099700444794, 30.60039295221194, 247.7593201754386, 212.40634637535763, 107.51567055393586, 157.36081451659956, 47.52422251423565, 85.66429362442652, 100.07867042611493, 97.18928236610518, 135.66782389143128, 81.25525558751936, 167.67263076791372, 102.25777488614183, 44.969848316685166, 136.11912110747792, 200.21563187601646, 148.0682975043242, 52.97460889906915]
# fliers:  []
# Thursday - AL list size: 28920
# Thursday - AL list size of data above 1000: 144
# Thursday - AR list size: 22187
# Thursday - AR list size of data above 1000: 494
# Thursday - AZ list size: 32298
# Thursday - AZ list size of data above 1000: 35
# Thursday - CA list size: 21596
# Thursday - CA list size of data above 1000: 14
# Thursday - CT list size: 8519
# Thursday - CT list size of data above 1000: 188
# Thursday - DE list size: 33028
# Thursday - DE list size of data above 1000: 86
# Thursday - GA list size: 14383
# Thursday - GA list size of data above 1000: 42
# Thursday - IA list size: 7960
# Thursday - IA list size of data above 1000: 147
# Thursday - ID list size: 25814
# Thursday - ID list size of data above 1000: 100
# Thursday - IL list size: 14956
# Thursday - IL list size of data above 1000: 70
# Thursday - KS list size: 16886
# Thursday - KS list size of data above 1000: 286
# Thursday - LA list size: 12868
# Thursday - LA list size of data above 1000: 63
# Thursday - MA list size: 31207
# Thursday - MA list size of data above 1000: 45
# Thursday - MD list size: 25109
# Thursday - MD list size of data above 1000: 51
# Thursday - ME list size: 33061
# Thursday - ME list size of data above 1000: 218
# Thursday - MI list size: 5437
# Thursday - MI list size of data above 1000: 291
# Thursday - MN list size: 15389
# Thursday - MN list size of data above 1000: 384
# Thursday - MS list size: 21591
# Thursday - MS list size of data above 1000: 172
# Thursday - MT list size: 20486
# Thursday - MT list size of data above 1000: 28
# Thursday - NC list size: 19876
# Thursday - NC list size of data above 1000: 2
# Thursday - ND list size: 32377
# Thursday - ND list size of data above 1000: 569
# Thursday - NE list size: 32064
# Thursday - NE list size of data above 1000: 32
# Thursday - NH list size: 19747
# Thursday - NH list size of data above 1000: 475
# Thursday - NM list size: 20573
# Thursday - NM list size of data above 1000: 7
# Thursday total: 516332
#
# whiskers:  [1.0, 112.0, 33.0, 884.0, 0.0, 193.0, 0.0, 119.0, 2.0, 288.0, 0.0, 152.0, 0.0, 136.0, 1.0, 267.0, 150.0, 254.0, 0.0, 302.0, 0.0, 186.0, 0.0, 116.0, 0.0, 188.0, 0.0, 287.0, 1.0, 300.0, 2.0, 473.0, 2.0, 226.0, 1.0, 229.0, 0.0, 189.0, 1.0, 114.0, 0.0, 156.0, 162.0, 259.0, 0.0, 265.0, 0.0, 109.0]
# caps:  [1.0, 112.0, 33.0, 884.0, 0.0, 193.0, 0.0, 119.0, 2.0, 288.0, 0.0, 152.0, 0.0, 136.0, 1.0, 267.0, 150.0, 254.0, 0.0, 302.0, 0.0, 186.0, 0.0, 116.0, 0.0, 188.0, 0.0, 287.0, 1.0, 300.0, 2.0, 473.0, 2.0, 226.0, 1.0, 229.0, 0.0, 189.0, 1.0, 114.0, 0.0, 156.0, 162.0, 259.0, 0.0, 265.0, 0.0, 109.0]
# boxes:  [12.0, 352.0, 18.0, 14.0, 28.0, 15.0, 11.0, 20.0, 189.0, 25.0, 11.0, 6.0, 13.0, 22.0, 23.0, 24.0, 21.0, 22.0, 17.0, 9.0, 9.0, 177.0, 13.0, 12.0]
# medians:  [25.0, 481.0, 44.0, 28.0, 56.0, 36.0, 26.0, 39.0, 198.0, 55.0, 24.0, 19.0, 35.0, 60.0, 57.0, 87.0, 45.0, 50.0, 39.0, 23.0, 24.0, 187.0, 38.0, 24.0]
# means:  [54.7417704011065, 493.08063280299274, 70.96074060313332, 43.30065752917207, 212.5263528583167, 65.93236042146057, 49.38510741848015, 155.1184673366834, 216.85073990857674, 112.43868681465632, 238.39322515693473, 48.422287845819085, 63.745666036466176, 100.00386315663707, 110.53652339614652, 225.74121758322605, 124.59990902592762, 95.88652679357139, 73.61241823684468, 37.27767156369491, 126.7230132501467, 203.6529129241517, 143.38679293057174, 43.4489379283527]
# fliers:  []
# Friday - AL list size: 30229
# Friday - AL list size of data above 1000: 64
# Friday - AR list size: 22103
# Friday - AR list size of data above 1000: 434
# Friday - AZ list size: 32973
# Friday - AZ list size of data above 1000: 27
# Friday - CA list size: 21590
# Friday - CA list size of data above 1000: 6
# Friday - CT list size: 10538
# Friday - CT list size of data above 1000: 85
# Friday - DE list size: 32991
# Friday - DE list size of data above 1000: 137
# Friday - GA list size: 15050
# Friday - GA list size of data above 1000: 12
# Friday - IA list size: 8458
# Friday - IA list size of data above 1000: 209
# Friday - ID list size: 25189
# Friday - ID list size of data above 1000: 209
# Friday - IL list size: 14029
# Friday - IL list size of data above 1000: 170
# Friday - KS list size: 17775
# Friday - KS list size of data above 1000: 472
# Friday - LA list size: 15071
# Friday - LA list size of data above 1000: 96
# Friday - MA list size: 30353
# Friday - MA list size of data above 1000: 56
# Friday - MD list size: 27040
# Friday - MD list size of data above 1000: 96
# Friday - ME list size: 33108
# Friday - ME list size of data above 1000: 216
# Friday - MI list size: 6143
# Friday - MI list size of data above 1000: 103
# Friday - MN list size: 17590
# Friday - MN list size of data above 1000: 147
# Friday - MS list size: 21597
# Friday - MS list size of data above 1000: 187
# Friday - MT list size: 20959
# Friday - MT list size of data above 1000: 200
# Friday - NC list size: 20838
# Friday - NC list size of data above 1000: 24
# Friday - ND list size: 32829
# Friday - ND list size of data above 1000: 220
# Friday - NE list size: 33056
# Friday - NE list size of data above 1000: 14
# Friday - NH list size: 19534
# Friday - NH list size of data above 1000: 416
# Friday - NM list size: 18848
# Friday - NM list size of data above 1000: 26
# Friday total: 527891
#
# whiskers:  [1.0, 157.0, 208.0, 806.0, 1.0, 226.0, 0.0, 122.0, 1.0, 203.0, 1.0, 156.0, 1.0, 103.0, 3.0, 374.0, 179.0, 267.0, 3.0, 346.0, 1.0, 401.0, 1.0, 131.0, 0.0, 194.0, 0.0, 296.0, 1.0, 354.0, 5.0, 382.0, 1.0, 228.0, 2.0, 228.0, 1.0, 268.0, 0.0, 123.0, 0.0, 119.0, 154.0, 258.0, 1.0, 330.0, 0.0, 144.0]
# caps:  [1.0, 157.0, 208.0, 806.0, 1.0, 226.0, 0.0, 122.0, 1.0, 203.0, 1.0, 156.0, 1.0, 103.0, 3.0, 374.0, 179.0, 267.0, 3.0, 346.0, 1.0, 401.0, 1.0, 131.0, 0.0, 194.0, 0.0, 296.0, 1.0, 354.0, 5.0, 382.0, 1.0, 228.0, 2.0, 228.0, 1.0, 268.0, 0.0, 123.0, 0.0, 119.0, 154.0, 258.0, 1.0, 330.0, 0.0, 144.0]
# boxes:  [15.0, 404.0, 21.0, 10.0, 27.0, 19.0, 13.0, 22.0, 192.0, 26.0, 19.0, 14.0, 17.0, 19.0, 27.0, 38.0, 18.0, 23.0, 20.0, 13.0, 9.0, 178.0, 18.0, 12.0]
# medians:  [33.0, 500.0, 49.0, 29.0, 50.0, 38.0, 27.0, 59.0, 200.0, 61.0, 52.0, 32.0, 38.0, 57.0, 64.0, 110.0, 44.0, 52.0, 45.0, 31.0, 21.0, 189.0, 49.0, 29.0]
# means:  [55.74769261305369, 507.1135592453513, 75.97188608861796, 41.282121352478, 101.43509204782691, 68.23515504228426, 41.2912292358804, 208.98888626152754, 245.91099289372346, 130.51500463325968, 462.2437130801688, 68.40322473624842, 73.75748690409515, 105.15188609467455, 120.29110788933188, 159.0610450919746, 90.95554292211484, 107.32736028152058, 108.26375304165275, 48.71345618581438, 64.84598982606842, 202.09831800580832, 150.84667758779563, 52.340407470288625]
# fliers:  []
# Saturday - AL list size: 29571
# Saturday - AL list size of data above 1000: 102
# Saturday - AR list size: 19456
# Saturday - AR list size of data above 1000: 367
# Saturday - AZ list size: 33006
# Saturday - AZ list size of data above 1000: 87
# Saturday - CA list size: 21597
# Saturday - CA list size of data above 1000: 41
# Saturday - CT list size: 9051
# Saturday - CT list size of data above 1000: 100
# Saturday - DE list size: 32950
# Saturday - DE list size of data above 1000: 251
# Saturday - GA list size: 15483
# Saturday - GA list size of data above 1000: 53
# Saturday - IA list size: 8705
# Saturday - IA list size of data above 1000: 216
# Saturday - ID list size: 24046
# Saturday - ID list size of data above 1000: 18
# Saturday - IL list size: 16236
# Saturday - IL list size of data above 1000: 117
# Saturday - KS list size: 16912
# Saturday - KS list size of data above 1000: 325
# Saturday - LA list size: 13627
# Saturday - LA list size of data above 1000: 1
# Saturday - MA list size: 30232
# Saturday - MA list size of data above 1000: 142
# Saturday - MD list size: 25043
# Saturday - MD list size of data above 1000: 208
# Saturday - ME list size: 33058
# Saturday - ME list size of data above 1000: 184
# Saturday - MI list size: 6652
# Saturday - MI list size of data above 1000: 132
# Saturday - MN list size: 16773
# Saturday - MN list size of data above 1000: 113
# Saturday - MS list size: 21766
# Saturday - MS list size of data above 1000: 66
# Saturday - MT list size: 18623
# Saturday - MT list size of data above 1000: 178
# Saturday - NC list size: 22322
# Saturday - NC list size of data above 1000: 60
# Saturday - ND list size: 33034
# Saturday - ND list size of data above 1000: 806
# Saturday - NE list size: 32661
# Saturday - NE list size of data above 1000: 79
# Saturday - NH list size: 19461
# Saturday - NH list size of data above 1000: 536
# Saturday - NM list size: 16807
# Saturday - NM list size of data above 1000: 49
# Saturday total: 517072
#
# whiskers:  [0.0, 132.0, 185.0, 794.0, 1.0, 191.0, 0.0, 108.0, 0.0, 218.0, 1.0, 154.0, 0.0, 106.0, 1.0, 269.0, 167.0, 257.0, 3.0, 286.0, 1.0, 202.0, 0.0, 119.0, 0.0, 197.0, 0.0, 335.0, 1.0, 286.0, 0.0, 434.0, 1.0, 162.0, 2.0, 215.0, 1.0, 223.0, 1.0, 101.0, 0.0, 134.0, 159.0, 244.0, 0.0, 295.0, 1.0, 139.0]
# caps:  [0.0, 132.0, 185.0, 794.0, 1.0, 191.0, 0.0, 108.0, 0.0, 218.0, 1.0, 154.0, 0.0, 106.0, 1.0, 269.0, 167.0, 257.0, 3.0, 286.0, 1.0, 202.0, 0.0, 119.0, 0.0, 197.0, 0.0, 335.0, 1.0, 286.0, 0.0, 434.0, 1.0, 162.0, 2.0, 215.0, 1.0, 223.0, 1.0, 101.0, 0.0, 134.0, 159.0, 244.0, 0.0, 295.0, 1.0, 139.0]
# boxes:  [15.0, 413.0, 21.0, 11.0, 18.0, 17.0, 11.0, 24.0, 190.0, 24.0, 22.0, 14.0, 17.0, 23.0, 24.0, 59.0, 15.0, 23.0, 21.0, 11.0, 9.0, 177.0, 23.0, 12.0]
# medians:  [32.0, 498.0, 42.0, 26.0, 47.0, 36.0, 28.0, 50.0, 199.0, 54.0, 42.0, 30.0, 44.0, 61.0, 55.0, 109.0, 34.0, 51.0, 46.0, 25.0, 23.0, 187.0, 52.0, 26.0]
# means:  [64.49545162490277, 522.263671875, 79.84878506938132, 42.24466361068667, 103.63109048723898, 80.00003034901366, 42.78854227216948, 152.34681217690982, 210.60883306994927, 120.10513673318552, 428.78914380321663, 46.46202392309386, 77.8540949986769, 149.4556562712135, 107.48145683344426, 191.07922429344558, 84.60066773981995, 80.75957916015804, 108.63061805294528, 43.901666517337155, 152.3470969304353, 202.21444536297113, 171.13945840398748, 56.67680133277801]
# fliers:  []
# Sunday - AL list size: 27790
# Sunday - AL list size of data above 1000: 270
# Sunday - AR list size: 18718
# Sunday - AR list size of data above 1000: 437
# Sunday - AZ list size: 30979
# Sunday - AZ list size of data above 1000: 255
# Sunday - CA list size: 21592
# Sunday - CA list size of data above 1000: 8
# Sunday - CT list size: 10176
# Sunday - CT list size of data above 1000: 183
# Sunday - DE list size: 31907
# Sunday - DE list size of data above 1000: 276
# Sunday - GA list size: 16253
# Sunday - GA list size of data above 1000: 139
# Sunday - IA list size: 8872
# Sunday - IA list size of data above 1000: 154
# Sunday - ID list size: 23635
# Sunday - ID list size of data above 1000: 178
# Sunday - IL list size: 14345
# Sunday - IL list size of data above 1000: 39
# Sunday - KS list size: 16531
# Sunday - KS list size of data above 1000: 286
# Sunday - LA list size: 12293
# Sunday - LA list size of data above 1000: 33
# Sunday - MA list size: 30236
# Sunday - MA list size of data above 1000: 89
# Sunday - MD list size: 21589
# Sunday - MD list size of data above 1000: 130
# Sunday - ME list size: 31620
# Sunday - ME list size of data above 1000: 152
# Sunday - MI list size: 6223
# Sunday - MI list size of data above 1000: 141
# Sunday - MN list size: 15822
# Sunday - MN list size of data above 1000: 86
# Sunday - MS list size: 22725
# Sunday - MS list size of data above 1000: 321
# Sunday - MT list size: 16889
# Sunday - MT list size of data above 1000: 204
# Sunday - NC list size: 20953
# Sunday - NC list size of data above 1000: 44
# Sunday - ND list size: 31733
# Sunday - ND list size of data above 1000: 375
# Sunday - NE list size: 31915
# Sunday - NE list size of data above 1000: 41
# Sunday - NH list size: 19696
# Sunday - NH list size of data above 1000: 373
# Sunday - NM list size: 18636
# Sunday - NM list size of data above 1000: 18
# Sunday total: 501128
#
# whiskers:  [0.0, 158.0, 61.0, 856.0, 0.0, 236.0, 0.0, 113.0, 1.0, 238.0, 1.0, 152.0, 1.0, 142.0, 1.0, 430.0, 123.0, 302.0, 1.0, 365.0, 0.0, 219.0, 1.0, 135.0, 0.0, 189.0, 0.0, 370.0, 0.0, 317.0, 9.0, 407.0, 2.0, 226.0, 1.0, 278.0, 0.0, 346.0, 0.0, 128.0, 0.0, 118.0, 150.0, 256.0, 1.0, 291.0, 0.0, 158.0]
# caps:  [0.0, 158.0, 61.0, 856.0, 0.0, 236.0, 0.0, 113.0, 1.0, 238.0, 1.0, 152.0, 1.0, 142.0, 1.0, 430.0, 123.0, 302.0, 1.0, 365.0, 0.0, 219.0, 1.0, 135.0, 0.0, 189.0, 0.0, 370.0, 0.0, 317.0, 9.0, 407.0, 2.0, 226.0, 1.0, 278.0, 0.0, 346.0, 0.0, 128.0, 0.0, 118.0, 150.0, 256.0, 1.0, 291.0, 0.0, 158.0]
# boxes:  [16.0, 359.0, 19.0, 11.0, 21.0, 17.0, 15.0, 30.0, 190.0, 25.0, 17.0, 10.0, 14.0, 23.0, 22.0, 78.5, 21.0, 23.0, 34.0, 11.0, 8.0, 179.0, 21.0, 11.0]
# medians:  [32.0, 489.0, 54.0, 28.0, 48.0, 39.0, 35.0, 82.0, 202.0, 64.0, 45.0, 27.0, 37.0, 69.0, 59.0, 132.0, 50.0, 59.0, 71.0, 23.0, 22.0, 191.0, 53.0, 30.0]
# means:  [76.15498380712486, 497.5010150657121, 95.03353884889763, 43.05293627269359, 133.86379716981133, 80.27874761024226, 72.28874669291822, 181.16805680793507, 234.6060926591919, 109.05158591843848, 326.2997398826447, 52.467501830309935, 67.62220531816378, 128.64074297095743, 109.55015812776723, 204.55825164711553, 94.2199469093667, 121.93936193619362, 133.13286754692405, 48.39574285305207, 109.45306148173826, 204.74902083659723, 138.3029549147035, 52.436628031766475]
# fliers:  []
