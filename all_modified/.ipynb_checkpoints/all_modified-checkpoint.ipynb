# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.4

# %%
import sys
# Add the path to system, local or mounted S3 bucket, e.g. /dbfs/mnt/<path_to_bucket>
sys.path.append('./secrets.py')

import logging
import math
import os

from influxdb import DataFrameClient
import numpy as np
import matplotlib.mlab as mlab
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate
from tqdm import tqdm
# %matplotlib inline

logging.basicConfig(level=logging.INFO)
LOGGER = logging.getLogger(__name__)

# Need to ssh tunnel for this to work
# ssh -L 8086:localhost:8086 aq.byu.edu -N
influx = DataFrameClient(
    host=HOST,
    port=PORT,
    username=USERNAME,
    password=PASSWORD,
    database=DATABASE,
)


def large_query(influx, measurement, query, total=None, limit=100_000):
    if total is not None:
        total = math.ceil(total / limit)

    with tqdm(total=total) as pbar:
        offset = 0
        while True:
            new_query = query + " LIMIT {} OFFSET {}".format(limit, offset)
            data = influx.query(new_query)
            data = data[measurement]

            received = len(data)
            pbar.update(1)

            yield data

            offset += limit
            if received != limit:
                break


def load_data(filename):
    if os.path.exists(filename):
        LOGGER.info("Loading cached data...")
        return pd.read_hdf(filename)

    LOGGER.info("Downloading data...")
    result = influx.query(
        "SELECT COUNT(sequence) FROM air_quality_sensor WHERE time > '2019-10-01' AND time <= now()"
    )
    count = result["air_quality_sensor"].values[0][0]

    queries = large_query(
        influx,
        "air_quality_sensor",
        "SELECT * FROM air_quality_sensor WHERE time > '2019-10-01' AND time <= now()",
        count,
    )

    all_data = pd.concat(list(queries), sort=False)
    all_data.to_hdf(filename, "data")
    return all_data


data = load_data("aq_data.h5")
gold_data = load_data("aq_data.h5")

LOGGER.info("Done loading data...")
# Out:
# INFO:__main__:Loading cached data...
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:__main__:Loading cached data...
# INFO:__main__:Done loading data...

# %%
# all_modified_gers - This is the working boxplot for all_modified_gers only Mongolia deployed sensors
# https://stackoverflow.com/questions/22800079/converting-time-zone-pandas-dataframe
# https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.between_time.html

# Don't include sensors: FL, IA, KS, MB, NB, NJ, NL, OR, WA, WY
# Look more closely at: NE, NS

from IPython.core.debugger import set_trace 
# https://matplotlib.org/3.1.3/gallery/statistics/boxplot_color.html 
print(data.index[1])
data.index = data.index.tz_convert('Asia/Ulaanbaatar')
print(data.index[1])

labels = ['All Modified Gers']
plt.xlabel('')
plt.ylabel('PM 2.5 Value')
plt.title('Week PM 2.5 for All Modified Gers Sensors')
plt.grid(True)
days = ['05', '06', '07', '08', '09', '10', '11']

# Clean up data this way:
data.loc[data['pm2_5'] > 1000, 'pm2_5'] = 1000
data.loc[data['pm2_5'] < 0, 'pm2_5'] = 0
# data['pm2_5'] = np.where(data['pm2_5'] >= 5000, 5000, data['pm2_5'])

data = data[data.location_name == 'Mongolia']

# start clean up data mode when in office or switched from outdoor to indoor or vice versa

# -------------------------- In Office ----------------------------------------------------------------------------------------------------------------------------
ak = data[data.index < '2020-02-15'].groupby("name").get_group('AK')
co = data[data.index < '2020-02-15'].groupby("name").get_group('CO')
ky = data[data.index < '2020-02-15'].groupby("name").get_group('KY')

# mb = data[data.index < '2020-02-15'].groupby("name").get_group('MB')
# mb = mb[(mb.index < '2020-01-26') | (mb.index >= '2020-02-04')]

# nj = data[(data.index < '2020-01-28') | (data.index >= '2020-02-04')].groupby("name").get_group('NJ')
nu = data[(data.index < '2020-01-26') | (data.index >= '2020-02-04')].groupby("name").get_group('NU')
# oregon = data[(data.index < '2020-01-26') | (data.index >= '2020-02-04')].groupby("name").get_group('OR')
pe = data[(data.index < '2020-02-11')].groupby("name").get_group('PE') #outdoor sensor we are no longer using these sensors data
# wy = data[(data.index < '2020-02-11')].groupby("name").get_group('WY') 

# --------------------------------------- Switched ---------------------------------------------------------------------------------------------------------------

ab = data[(data.index > '2020-01-28') & (data.index <= '2020-02-14')].groupby("name").get_group('AB') # outdoor sensor we are no longer using these sensors data before but will use after the switch to indoor
ns = data[(data.index >= '2020-01-28')].groupby("name").get_group('NS') # outdoor sensor we are no longer using these sensors data before but will use after the switch to indoor
# oregon = oregon[(oregon.index >= '2020-01-28')] # outdoor sensor we are no longer using these sensors data before but will use after the switch to indoor
ut = data[(data.index >= '2020-01-29')].groupby("name").get_group('UT') # outdoor sensor we are no longer using these sensors data before but will use after the switch to indoor

# finish clean up data mode when in office or switched from outdoor to indoor or vice versa
# ------------------------------------------------------------------------------------------------------------------------------------------------------

modified_gers = ['AL', 'AR', 'AZ', 'CA', 'CT', 'DE', 'ID', 'IL', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'NH', 'NM', 'GA', 'ND', 'NE']
modified_gers_data = data[(data.name == modified_gers[0]) | (data.name == modified_gers[1]) | (data.name == modified_gers[2]) | (data.name == modified_gers[3]) | (data.name == modified_gers[4]) | (data.name == modified_gers[5]) | (data.name == modified_gers[6]) | (data.name == modified_gers[7]) | (data.name == modified_gers[8]) | (data.name == modified_gers[9]) | (data.name == modified_gers[10]) | (data.name == modified_gers[11]) | (data.name == modified_gers[12]) | (data.name == modified_gers[13]) | (data.name == modified_gers[14]) | (data.name == modified_gers[15]) | (data.name == modified_gers[16]) | (data.name == modified_gers[17]) | (data.name == modified_gers[18]) | (data.name == modified_gers[19]) | (data.name == modified_gers[20]) | (data.name == modified_gers[21])]
modified_gers_data = modified_gers_data.append(ak)
modified_gers_data = modified_gers_data.append(co)
modified_gers_data = modified_gers_data.append(ky)
# unmodified_gers = ['NJ', 'NS', 'NU', 'OK', 'OR', 'PA', 'RI', 'SD', 'UT', 'VA', 'WI']
# unmodified_gers_data = data[(data.name == unmodified_gers[0]) | (data.name == unmodified_gers[1]) | (data.name == unmodified_gers[2]) | (data.name == unmodified_gers[3]) | (data.name == unmodified_gers[4]) | (data.name == unmodified_gers[5]) | (data.name == unmodified_gers[6]) | (data.name == unmodified_gers[7]) | (data.name == unmodified_gers[8]) | (data.name == unmodified_gers[9]) | (data.name == unmodified_gers[10])]

unmodified_gers = ['OK', 'PA', 'RI', 'SD', 'VA', 'WI']
unmodified_gers_data = data[(data.name == unmodified_gers[0]) | (data.name == unmodified_gers[1]) | (data.name == unmodified_gers[2]) | (data.name == unmodified_gers[3]) | (data.name == unmodified_gers[4]) | (data.name == unmodified_gers[5])]
unmodified_gers_data = unmodified_gers_data.append(ab)
# unmodified_gers_data = unmodified_gers_data.append(mb)
# unmodified_gers_data = unmodified_gers_data.append(nj)
unmodified_gers_data = unmodified_gers_data.append(nu)
unmodified_gers_data = unmodified_gers_data.append(ns)
# unmodified_gers_data = unmodified_gers_data.append(oregon)
unmodified_gers_data = unmodified_gers_data.append(ut)
# Out:
# 2019-11-04 00:00:02+00:00
# 2019-11-04 08:00:02+08:00

# %%
labels = ['All Modified Gers']
plt.xlabel('')
plt.ylabel('PM 2.5 Value')
plt.title('Week PM 2.5 for All Modified Gers Sensors')
plt.grid(True)

all_sensors_names = []
for name, sensor_data in modified_gers_data.groupby("name"):
    all_sensors_names.append(name)
print("All Sensors names:", all_sensors_names)

day_names = modified_gers_data.index.day_name()
print(type(day_names))
print(day_names[:1000])

all_modified_gers = [modified_gers_data.pm2_5.dropna()]
print('{} list size: {}'.format(labels[0], len(data.pm2_5)))
results = plt.boxplot(all_modified_gers, showfliers=False, labels=labels, showmeans=True, meanline=True)

# print(results)
print('whiskers: ', [item.get_ydata()[1] for item in results['whiskers']])
print('caps: ', [item.get_ydata()[1] for item in results['caps']])
print('boxes: ', [item.get_ydata()[1] for item in results['boxes']])
print('medians: ', [item.get_ydata()[1] for item in results['medians']])
print('means: ', [item.get_ydata()[1] for item in results['means']])
print('fliers: ', [item.get_ydata()[1] for item in results['fliers']])
# Out:
# All Sensors names: ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DE', 'GA', 'ID', 'IL', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NM']
# <class 'pandas.core.indexes.base.Index'>
# Index(['Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday',
#        'Monday', 'Monday', 'Monday',
#        ...
#        'Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday',
#        'Monday', 'Monday', 'Monday'],
#       dtype='object', length=1000)
# All Modified Gers list size: 6288186
# whiskers:  [0.0, 383.0]
# caps:  [0.0, 383.0]
# boxes:  [18.0]
# medians:  [50.0]
# means:  [110.63126388111992]
# fliers:  []

# %%
labels = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
plt.xlabel('Dates')
plt.ylabel('PM 2.5 Value')
plt.title('Week PM 2.5 for sensors')
plt.grid(True)

all_sensors_names = []
for name, sensor_data in modified_gers_data.groupby("name"):
    all_sensors_names.append(name)
print("All Sensors names:", all_sensors_names)

day_names = modified_gers_data.index.day_name()
print(type(day_names))
print(day_names[:10])

monday = modified_gers_data[(modified_gers_data.index.day_name() == 'Monday')]['pm2_5'].dropna()
tuesday = modified_gers_data[modified_gers_data.index.day_name() == 'Tuesday']['pm2_5'].dropna()
wednesday = modified_gers_data[modified_gers_data.index.day_name() == 'Wednesday']['pm2_5'].dropna()
thursday = modified_gers_data[modified_gers_data.index.day_name() == 'Thursday']['pm2_5'].dropna()
friday = modified_gers_data[modified_gers_data.index.day_name() == 'Friday']['pm2_5'].dropna()
saturday = modified_gers_data[modified_gers_data.index.day_name() == 'Saturday']['pm2_5'].dropna()
sunday = modified_gers_data[modified_gers_data.index.day_name() == 'Sunday']['pm2_5'].dropna()
all_days = [monday, tuesday, wednesday, thursday, friday, saturday, sunday]

results = plt.boxplot(all_days, showfliers=False, labels=labels, showmeans=True, meanline=True)

i = 0
cumulative = 0
for day in all_days:
    print('{} list size: {}'.format(labels[i], len(day)))
    cumulative += len(day)
    i+= 1
print('total for all days: {}'.format(cumulative))
print()

# print(results)
print('whiskers: ', [item.get_ydata()[1] for item in results['whiskers']])
print('caps: ', [item.get_ydata()[1] for item in results['caps']])
print('boxes: ', [item.get_ydata()[1] for item in results['boxes']])
print('medians: ', [item.get_ydata()[1] for item in results['medians']])
print('means: ', [item.get_ydata()[1] for item in results['means']])
print('fliers: ', [item.get_ydata()[1] for item in results['fliers']])
# Out:
# All Sensors names: ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DE', 'GA', 'ID', 'IL', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NM']
# <class 'pandas.core.indexes.base.Index'>
# Index(['Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday',
#        'Monday', 'Monday', 'Monday'],
#       dtype='object')
# Mon list size: 494286
# Tue list size: 511248
# Wed list size: 533416
# Thu list size: 525753
# Fri list size: 539008
# Sat list size: 529249
# Sun list size: 506876
# total for all days: 3639836
#
# whiskers:  [0.0, 347.0, 0.0, 363.0, 0.0, 391.0, 0.0, 395.0, 0.0, 396.0, 0.0, 375.0, 0.0, 395.0]
# caps:  [0.0, 347.0, 0.0, 363.0, 0.0, 391.0, 0.0, 395.0, 0.0, 396.0, 0.0, 375.0, 0.0, 395.0]
# boxes:  [17.0, 16.0, 16.0, 18.0, 21.0, 20.0, 20.0]
# medians:  [46.0, 47.0, 46.0, 51.0, 55.0, 50.0, 57.0]
# means:  [105.93356477828625, 106.05051168904328, 108.3418926316421, 112.10757523019365, 115.70870376691997, 110.43055348238731, 115.52075261010583]
# fliers:  []

# %%
# modified_gers each sensors - This is the working boxplot for modified_gers only Mongolia deployed sensors

plt.xlabel('Sensors')
plt.ylabel('PM 2.5 Value')
plt.title('Week PM 2.5 for sensors')
plt.grid(True)
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

all_sensors_names = []
for name, sensor_data in modified_gers_data.groupby("name"):
    all_sensors_names.append(name)
print("All Sensors names:", all_sensors_names)

day_names = modified_gers_data.index.day_name()
print(type(day_names))
print(day_names[:10])

for day in days_of_week:
    plt.xlabel('Sensors for {0}'.format(day))
    plt.ylabel('PM 2.5 Value')
    plt.title('Week PM 2.5 for sensors for {0}'.format(day))
    plt.grid(True)
    sensors_data = list()
    sensors_name = list()
    temp = modified_gers_data[modified_gers_data.index.day_name() == day]
    # temp = temp.groupby("name")
    cumulative = 0
    for name, sensor_data in temp.groupby("name"):
        sensors_name.append(name)
        sensors_data.append(temp.groupby("name").get_group(name)["pm2_5"].dropna().to_numpy().tolist())
        cumulative += len(sensor_data)
        print('{} - {} list size: {}'.format(day, name,  len(sensor_data)))
        print('{} - {} list size of data above 1000: {}'.format(day, name,  len(sensor_data[sensor_data.pm2_5 > 1000])))
    print ('{} total: {}'.format(day, cumulative))    
    print()
    results = plt.boxplot(sensors_data, showfliers=False, labels=sensors_name, showmeans=True, meanline=True)
    print('whiskers: ', [item.get_ydata()[1] for item in results['whiskers']])
    print('caps: ', [item.get_ydata()[1] for item in results['caps']])
    print('boxes: ', [item.get_ydata()[1] for item in results['boxes']])
    print('medians: ', [item.get_ydata()[1] for item in results['medians']])
    print('means: ', [item.get_ydata()[1] for item in results['means']])
    print('fliers: ', [item.get_ydata()[1] for item in results['fliers']])
    plt.show()
# Out:
# All Sensors names: ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DE', 'GA', 'ID', 'IL', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NM']
# <class 'pandas.core.indexes.base.Index'>
# Index(['Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday',
#        'Monday', 'Monday', 'Monday'],
#       dtype='object')
# Monday - AK list size: 12958
# Monday - AK list size of data above 1000: 0
# Monday - AL list size: 27791
# Monday - AL list size of data above 1000: 0
# Monday - AR list size: 17644
# Monday - AR list size of data above 1000: 0
# Monday - AZ list size: 30875
# Monday - AZ list size of data above 1000: 0
# Monday - CA list size: 21565
# Monday - CA list size of data above 1000: 0
# Monday - CO list size: 17016
# Monday - CO list size of data above 1000: 0
# Monday - CT list size: 11207
# Monday - CT list size of data above 1000: 0
# Monday - DE list size: 31261
# Monday - DE list size of data above 1000: 0
# Monday - GA list size: 17265
# Monday - GA list size of data above 1000: 0
# Monday - ID list size: 25435
# Monday - ID list size of data above 1000: 0
# Monday - IL list size: 23413
# Monday - IL list size of data above 1000: 0
# Monday - KY list size: 10461
# Monday - KY list size of data above 1000: 0
# Monday - LA list size: 17459
# Monday - LA list size of data above 1000: 0
# Monday - MA list size: 30227
# Monday - MA list size of data above 1000: 0
# Monday - MD list size: 21613
# Monday - MD list size of data above 1000: 0
# Monday - ME list size: 31657
# Monday - ME list size of data above 1000: 0
# Monday - MI list size: 7079
# Monday - MI list size of data above 1000: 0
# Monday - MN list size: 18321
# Monday - MN list size of data above 1000: 0
# Monday - MS list size: 20895
# Monday - MS list size of data above 1000: 0
# Monday - MT list size: 20043
# Monday - MT list size of data above 1000: 0
# Monday - NC list size: 24000
# Monday - NC list size of data above 1000: 0
# Monday - ND list size: 30686
# Monday - ND list size of data above 1000: 0
# Monday - NE list size: 29935
# Monday - NE list size of data above 1000: 0
# Monday - NH list size: 23865
# Monday - NH list size of data above 1000: 0
# Monday - NM list size: 21200
# Monday - NM list size of data above 1000: 0
# Monday total: 543871
#
# whiskers:  [25.0, 401.0, 1.0, 129.0, 71.0, 841.0, 1.0, 212.0, 0.0, 88.0, 1.0, 124.0, 3.0, 306.0, 1.0, 146.0, 1.0, 98.0, 140.0, 271.0, 3.0, 247.0, 1.0, 131.0, 0.0, 100.0, 1.0, 166.0, 0.0, 269.0, 1.0, 274.0, 6.0, 521.0, 1.0, 176.0, 1.0, 211.0, 1.0, 282.0, 0.0, 109.0, 1.0, 141.0, 163.0, 247.0, 1.0, 230.0, 1.0, 131.0]
# caps:  [25.0, 401.0, 1.0, 129.0, 71.0, 841.0, 1.0, 212.0, 0.0, 88.0, 1.0, 124.0, 3.0, 306.0, 1.0, 146.0, 1.0, 98.0, 140.0, 271.0, 3.0, 247.0, 1.0, 131.0, 0.0, 100.0, 1.0, 166.0, 0.0, 269.0, 1.0, 274.0, 6.0, 521.0, 1.0, 176.0, 1.0, 211.0, 1.0, 282.0, 0.0, 109.0, 1.0, 141.0, 163.0, 247.0, 1.0, 230.0, 1.0, 131.0]
# boxes:  [166.0, 12.0, 360.0, 20.0, 11.0, 17.0, 21.0, 16.0, 13.0, 189.0, 22.0, 14.0, 8.0, 14.0, 22.0, 19.0, 66.0, 19.0, 16.0, 25.0, 9.0, 9.0, 177.0, 13.0, 9.0]
# medians:  [217.0, 27.0, 477.0, 48.0, 21.0, 36.0, 44.0, 35.0, 27.0, 197.0, 50.0, 31.0, 24.0, 34.0, 51.0, 53.0, 128.0, 43.0, 44.0, 57.0, 23.0, 23.0, 186.0, 41.0, 22.0]
# means:  [247.4543323493662, 51.327391883619605, 467.37628016480284, 79.90011297933142, 33.50391838627406, 53.88071674132722, 125.3100806863446, 60.28158914108269, 38.5828081232493, 210.26853291861067, 92.19710323153652, 48.37043991416309, 43.85782757950644, 62.41795143254152, 94.3611071682044, 95.33336494089386, 207.0387669313405, 74.01132000529591, 80.46537423803338, 119.30282277274893, 44.07276909404569, 92.67165285358129, 197.87107233587378, 109.3236572570572, 45.72382074148859]
# fliers:  []
# Tuesday - AK list size: 13689
# Tuesday - AK list size of data above 1000: 0
# Tuesday - AL list size: 27834
# Tuesday - AL list size of data above 1000: 0
# Tuesday - AR list size: 17430
# Tuesday - AR list size of data above 1000: 0
# Tuesday - AZ list size: 32125
# Tuesday - AZ list size of data above 1000: 0
# Tuesday - CA list size: 21984
# Tuesday - CA list size of data above 1000: 0
# Tuesday - CO list size: 17751
# Tuesday - CO list size of data above 1000: 0
# Tuesday - CT list size: 12271
# Tuesday - CT list size of data above 1000: 0
# Tuesday - DE list size: 32095
# Tuesday - DE list size of data above 1000: 0
# Tuesday - GA list size: 16540
# Tuesday - GA list size of data above 1000: 0
# Tuesday - ID list size: 26683
# Tuesday - ID list size of data above 1000: 0
# Tuesday - IL list size: 23121
# Tuesday - IL list size of data above 1000: 0
# Tuesday - KY list size: 11756
# Tuesday - KY list size of data above 1000: 0
# Tuesday - LA list size: 15996
# Tuesday - LA list size of data above 1000: 0
# Tuesday - MA list size: 30720
# Tuesday - MA list size of data above 1000: 0
# Tuesday - MD list size: 23170
# Tuesday - MD list size of data above 1000: 0
# Tuesday - ME list size: 32116
# Tuesday - ME list size of data above 1000: 0
# Tuesday - MI list size: 10153
# Tuesday - MI list size of data above 1000: 0
# Tuesday - MN list size: 19545
# Tuesday - MN list size of data above 1000: 0
# Tuesday - MS list size: 21074
# Tuesday - MS list size of data above 1000: 0
# Tuesday - MT list size: 23170
# Tuesday - MT list size of data above 1000: 0
# Tuesday - NC list size: 26191
# Tuesday - NC list size of data above 1000: 0
# Tuesday - ND list size: 30720
# Tuesday - ND list size of data above 1000: 0
# Tuesday - NE list size: 30704
# Tuesday - NE list size of data above 1000: 0
# Tuesday - NH list size: 24229
# Tuesday - NH list size of data above 1000: 0
# Tuesday - NM list size: 23114
# Tuesday - NM list size of data above 1000: 0
# Tuesday total: 564181
#
# whiskers:  [0.0, 491.0, 0.0, 162.0, 4.0, 843.0, 0.0, 224.0, 0.0, 96.0, 1.0, 156.0, 3.0, 205.0, 0.0, 146.0, 0.0, 89.0, 120.0, 315.0, 4.0, 361.0, 3.0, 159.0, 0.0, 87.0, 0.0, 181.0, 0.0, 315.0, 0.0, 344.0, 2.0, 326.0, 0.0, 247.0, 0.0, 198.0, 0.0, 272.0, 0.0, 110.0, 0.0, 108.0, 164.0, 273.0, 2.0, 255.0, 0.0, 152.0]
# caps:  [0.0, 491.0, 0.0, 162.0, 4.0, 843.0, 0.0, 224.0, 0.0, 96.0, 1.0, 156.0, 3.0, 205.0, 0.0, 146.0, 0.0, 89.0, 120.0, 315.0, 4.0, 361.0, 3.0, 159.0, 0.0, 87.0, 0.0, 181.0, 0.0, 315.0, 0.0, 344.0, 2.0, 326.0, 0.0, 247.0, 0.0, 198.0, 0.0, 272.0, 0.0, 110.0, 0.0, 108.0, 164.0, 273.0, 2.0, 255.0, 0.0, 152.0]
# boxes:  [169.0, 10.0, 311.0, 17.0, 9.0, 19.0, 18.0, 16.0, 9.0, 190.0, 26.0, 12.0, 7.0, 14.0, 18.0, 19.0, 34.0, 17.0, 16.0, 20.0, 10.0, 8.0, 178.0, 18.0, 10.0]
# medians:  [224.0, 25.0, 446.0, 45.0, 22.0, 51.0, 41.0, 33.0, 19.0, 201.0, 67.0, 30.0, 17.0, 38.0, 57.0, 48.0, 76.0, 46.0, 41.0, 53.0, 23.0, 22.0, 191.0, 49.0, 25.0]
# means:  [274.2146114471847, 57.31594452827477, 438.63496809061115, 76.06324358171571, 37.54087990487515, 68.85372155420849, 98.29333109074089, 60.62768012964348, 37.30320516841247, 235.82679929783498, 109.55099794540652, 51.72868310282622, 40.73102018883856, 72.07208264085769, 105.42361502144064, 101.05029363988504, 129.9956857105504, 99.98492972850934, 80.42390446111331, 96.19992503396898, 36.01276825615086, 57.70688531003456, 208.9482460802551, 110.7241113225989, 52.53302473744463]
# fliers:  []
# Wednesday - AK list size: 16860
# Wednesday - AK list size of data above 1000: 0
# Wednesday - AL list size: 28544
# Wednesday - AL list size of data above 1000: 0
# Wednesday - AR list size: 20551
# Wednesday - AR list size of data above 1000: 0
# Wednesday - AZ list size: 33003
# Wednesday - AZ list size of data above 1000: 0
# Wednesday - CA list size: 21594
# Wednesday - CA list size of data above 1000: 0
# Wednesday - CO list size: 18697
# Wednesday - CO list size of data above 1000: 0
# Wednesday - CT list size: 13071
# Wednesday - CT list size of data above 1000: 0
# Wednesday - DE list size: 33117
# Wednesday - DE list size of data above 1000: 0
# Wednesday - GA list size: 15838
# Wednesday - GA list size of data above 1000: 0
# Wednesday - ID list size: 28252
# Wednesday - ID list size of data above 1000: 0
# Wednesday - IL list size: 23521
# Wednesday - IL list size of data above 1000: 0
# Wednesday - KY list size: 11110
# Wednesday - KY list size of data above 1000: 0
# Wednesday - LA list size: 14889
# Wednesday - LA list size of data above 1000: 0
# Wednesday - MA list size: 31680
# Wednesday - MA list size of data above 1000: 0
# Wednesday - MD list size: 25523
# Wednesday - MD list size of data above 1000: 0
# Wednesday - ME list size: 33117
# Wednesday - ME list size of data above 1000: 0
# Wednesday - MI list size: 9615
# Wednesday - MI list size of data above 1000: 0
# Wednesday - MN list size: 20624
# Wednesday - MN list size of data above 1000: 0
# Wednesday - MS list size: 24142
# Wednesday - MS list size of data above 1000: 0
# Wednesday - MT list size: 25873
# Wednesday - MT list size of data above 1000: 0
# Wednesday - NC list size: 27821
# Wednesday - NC list size of data above 1000: 0
# Wednesday - ND list size: 32762
# Wednesday - ND list size of data above 1000: 0
# Wednesday - NE list size: 31647
# Wednesday - NE list size of data above 1000: 0
# Wednesday - NH list size: 24656
# Wednesday - NH list size of data above 1000: 0
# Wednesday - NM list size: 22993
# Wednesday - NM list size of data above 1000: 0
# Wednesday total: 589500
#
# whiskers:  [36.0, 473.0, 0.0, 122.0, 9.0, 849.0, 0.0, 198.0, 0.0, 114.0, 0.0, 158.0, 0.0, 197.0, 0.0, 167.0, 0.0, 81.0, 170.0, 249.0, 4.0, 338.0, 2.0, 143.0, 0.0, 78.0, 0.0, 175.0, 0.0, 307.0, 0.0, 272.0, 3.0, 252.0, 1.0, 174.0, 0.0, 254.0, 1.0, 263.0, 0.0, 103.0, 0.0, 113.0, 127.0, 255.0, 0.0, 311.0, 0.0, 110.0]
# caps:  [36.0, 473.0, 0.0, 122.0, 9.0, 849.0, 0.0, 198.0, 0.0, 114.0, 0.0, 158.0, 0.0, 197.0, 0.0, 167.0, 0.0, 81.0, 170.0, 249.0, 4.0, 338.0, 2.0, 143.0, 0.0, 78.0, 0.0, 175.0, 0.0, 307.0, 0.0, 272.0, 3.0, 252.0, 1.0, 174.0, 0.0, 254.0, 1.0, 263.0, 0.0, 103.0, 0.0, 113.0, 127.0, 255.0, 0.0, 311.0, 0.0, 110.0]
# boxes:  [181.0, 12.0, 324.0, 18.0, 9.0, 26.0, 20.0, 12.0, 9.0, 189.0, 21.0, 13.0, 6.0, 13.0, 17.0, 17.0, 30.0, 14.0, 15.0, 16.0, 11.0, 7.0, 175.0, 16.0, 10.0]
# medians:  [236.0, 28.0, 470.0, 39.0, 21.0, 54.0, 41.0, 28.0, 18.0, 196.0, 51.0, 34.0, 12.0, 36.0, 56.0, 46.0, 55.0, 35.0, 39.0, 41.0, 25.0, 20.0, 185.0, 52.0, 21.0]
# means:  [265.2729912875121, 53.12146679596308, 445.8965147975078, 72.59025315668346, 37.96508275990329, 77.43112523587249, 91.19978838014622, 66.12357408696178, 30.59754087970592, 211.78252145803143, 104.5518221574344, 54.04238898123961, 47.0437144108629, 70.47384907451352, 99.35133632500695, 94.82015302265098, 103.51743727315764, 77.76908608099137, 99.40403218902492, 97.77714161787031, 44.22549019607843, 70.70730067536596, 200.18033100545298, 132.20128490239685, 44.69847458453141]
# fliers:  []
# Thursday - AK list size: 17235
# Thursday - AK list size of data above 1000: 0
# Thursday - AL list size: 28926
# Thursday - AL list size of data above 1000: 0
# Thursday - AR list size: 22200
# Thursday - AR list size of data above 1000: 0
# Thursday - AZ list size: 32914
# Thursday - AZ list size of data above 1000: 0
# Thursday - CA list size: 21599
# Thursday - CA list size of data above 1000: 0
# Thursday - CO list size: 19826
# Thursday - CO list size of data above 1000: 0
# Thursday - CT list size: 9821
# Thursday - CT list size of data above 1000: 0
# Thursday - DE list size: 33105
# Thursday - DE list size of data above 1000: 0
# Thursday - GA list size: 15020
# Thursday - GA list size of data above 1000: 0
# Thursday - ID list size: 26095
# Thursday - ID list size of data above 1000: 0
# Thursday - IL list size: 24406
# Thursday - IL list size of data above 1000: 0
# Thursday - KY list size: 12115
# Thursday - KY list size of data above 1000: 0
# Thursday - LA list size: 16096
# Thursday - LA list size of data above 1000: 0
# Thursday - MA list size: 31676
# Thursday - MA list size of data above 1000: 0
# Thursday - MD list size: 25243
# Thursday - MD list size of data above 1000: 0
# Thursday - ME list size: 33072
# Thursday - ME list size of data above 1000: 0
# Thursday - MI list size: 8055
# Thursday - MI list size of data above 1000: 0
# Thursday - MN list size: 18122
# Thursday - MN list size of data above 1000: 0
# Thursday - MS list size: 21830
# Thursday - MS list size of data above 1000: 0
# Thursday - MT list size: 22777
# Thursday - MT list size of data above 1000: 0
# Thursday - NC list size: 26875
# Thursday - NC list size of data above 1000: 0
# Thursday - ND list size: 32987
# Thursday - ND list size of data above 1000: 0
# Thursday - NE list size: 32340
# Thursday - NE list size of data above 1000: 0
# Thursday - NH list size: 25084
# Thursday - NH list size of data above 1000: 0
# Thursday - NM list size: 23569
# Thursday - NM list size of data above 1000: 0
# Thursday total: 580988
#
# whiskers:  [68.0, 447.0, 1.0, 112.0, 33.0, 884.0, 0.0, 193.0, 0.0, 119.0, 3.0, 135.0, 2.0, 288.0, 0.0, 152.0, 0.0, 136.0, 150.0, 254.0, 0.0, 302.0, 2.0, 148.0, 0.0, 116.0, 0.0, 188.0, 0.0, 287.0, 1.0, 300.0, 2.0, 473.0, 2.0, 226.0, 1.0, 229.0, 0.0, 189.0, 1.0, 114.0, 0.0, 156.0, 162.0, 259.0, 0.0, 265.0, 0.0, 109.0]
# caps:  [68.0, 447.0, 1.0, 112.0, 33.0, 884.0, 0.0, 193.0, 0.0, 119.0, 3.0, 135.0, 2.0, 288.0, 0.0, 152.0, 0.0, 136.0, 150.0, 254.0, 0.0, 302.0, 2.0, 148.0, 0.0, 116.0, 0.0, 188.0, 0.0, 287.0, 1.0, 300.0, 2.0, 473.0, 2.0, 226.0, 1.0, 229.0, 0.0, 189.0, 1.0, 114.0, 0.0, 156.0, 162.0, 259.0, 0.0, 265.0, 0.0, 109.0]
# boxes:  [210.0, 12.0, 352.0, 18.0, 14.0, 35.0, 28.0, 15.0, 11.0, 189.0, 25.0, 18.0, 6.0, 13.0, 22.0, 23.0, 24.0, 21.0, 22.0, 17.0, 9.0, 9.0, 177.0, 13.0, 12.0]
# medians:  [243.0, 25.0, 481.0, 44.0, 28.0, 53.0, 56.0, 36.0, 26.0, 198.0, 55.0, 36.0, 19.0, 35.0, 60.0, 57.0, 87.0, 45.0, 50.0, 39.0, 23.0, 24.0, 187.0, 38.0, 24.0]
# means:  [286.80775339301186, 50.97814661134163, 470.0930683252208, 70.12911016161992, 42.720133358029265, 62.23211756373938, 130.35931447352976, 58.292176335230714, 47.85302092748383, 215.77070581854807, 111.19209681733084, 56.91368721210792, 47.14027043829655, 62.90697599897459, 98.43362937592099, 106.15668007622274, 184.1285635460732, 112.16888686724283, 88.96359594275393, 72.85931855901592, 36.76665325015094, 75.72236464156654, 203.34612025948104, 122.06588342533043, 43.368687114178776]
# fliers:  []
# Friday - AK list size: 16709
# Friday - AK list size of data above 1000: 0
# Friday - AL list size: 30229
# Friday - AL list size of data above 1000: 0
# Friday - AR list size: 23028
# Friday - AR list size of data above 1000: 0
# Friday - AZ list size: 33059
# Friday - AZ list size of data above 1000: 0
# Friday - CA list size: 21590
# Friday - CA list size of data above 1000: 0
# Friday - CO list size: 19176
# Friday - CO list size of data above 1000: 0
# Friday - CT list size: 11229
# Friday - CT list size of data above 1000: 0
# Friday - DE list size: 32996
# Friday - DE list size of data above 1000: 0
# Friday - GA list size: 15071
# Friday - GA list size of data above 1000: 0
# Friday - ID list size: 26712
# Friday - ID list size of data above 1000: 0
# Friday - IL list size: 24583
# Friday - IL list size of data above 1000: 0
# Friday - KY list size: 12743
# Friday - KY list size of data above 1000: 0
# Friday - LA list size: 17416
# Friday - LA list size of data above 1000: 0
# Friday - MA list size: 31163
# Friday - MA list size of data above 1000: 0
# Friday - MD list size: 27040
# Friday - MD list size of data above 1000: 0
# Friday - ME list size: 33117
# Friday - ME list size of data above 1000: 0
# Friday - MI list size: 7647
# Friday - MI list size of data above 1000: 0
# Friday - MN list size: 18682
# Friday - MN list size of data above 1000: 0
# Friday - MS list size: 21601
# Friday - MS list size of data above 1000: 0
# Friday - MT list size: 22168
# Friday - MT list size of data above 1000: 0
# Friday - NC list size: 27012
# Friday - NC list size of data above 1000: 0
# Friday - ND list size: 32829
# Friday - ND list size of data above 1000: 0
# Friday - NE list size: 33105
# Friday - NE list size of data above 1000: 0
# Friday - NH list size: 23884
# Friday - NH list size of data above 1000: 0
# Friday - NM list size: 21673
# Friday - NM list size of data above 1000: 0
# Friday total: 584462
#
# whiskers:  [44.0, 482.0, 1.0, 157.0, 208.0, 806.0, 1.0, 226.0, 0.0, 122.0, 1.0, 173.0, 1.0, 203.0, 1.0, 156.0, 1.0, 103.0, 179.0, 267.0, 3.0, 346.0, 1.0, 221.0, 1.0, 131.0, 0.0, 194.0, 0.0, 296.0, 1.0, 354.0, 5.0, 382.0, 1.0, 228.0, 2.0, 228.0, 1.0, 268.0, 0.0, 123.0, 0.0, 119.0, 154.0, 258.0, 1.0, 330.0, 0.0, 144.0]
# caps:  [44.0, 482.0, 1.0, 157.0, 208.0, 806.0, 1.0, 226.0, 0.0, 122.0, 1.0, 173.0, 1.0, 203.0, 1.0, 156.0, 1.0, 103.0, 179.0, 267.0, 3.0, 346.0, 1.0, 221.0, 1.0, 131.0, 0.0, 194.0, 0.0, 296.0, 1.0, 354.0, 5.0, 382.0, 1.0, 228.0, 2.0, 228.0, 1.0, 268.0, 0.0, 123.0, 0.0, 119.0, 154.0, 258.0, 1.0, 330.0, 0.0, 144.0]
# boxes:  [200.0, 15.0, 404.0, 21.0, 10.0, 28.0, 27.0, 19.0, 13.0, 192.0, 26.0, 14.0, 14.0, 17.0, 19.0, 27.0, 38.0, 18.0, 23.0, 20.0, 13.0, 9.0, 178.0, 18.0, 12.0]
# medians:  [248.0, 33.0, 500.0, 49.0, 29.0, 56.0, 50.0, 38.0, 27.0, 200.0, 61.0, 38.0, 32.0, 38.0, 57.0, 64.0, 110.0, 44.0, 52.0, 45.0, 31.0, 21.0, 189.0, 49.0, 29.0]
# means:  [279.2498427563072, 54.62115849019154, 494.97330679093335, 75.84393291480909, 41.074803149606296, 84.15190062855433, 90.31542987284115, 65.82280015761874, 41.00890365448505, 233.3838580332685, 128.06308361251692, 65.28944920946574, 66.25320151283923, 71.74068461107633, 100.62348372781065, 117.15041681768757, 148.6389386293342, 85.84115974985788, 93.49696717136639, 100.76377689775275, 47.668730204434205, 56.42706143958086, 201.3289569215876, 123.78263540493498, 51.581016553480474]
# fliers:  []
# Saturday - AK list size: 16390
# Saturday - AK list size of data above 1000: 0
# Saturday - AL list size: 30227
# Saturday - AL list size of data above 1000: 0
# Saturday - AR list size: 20422
# Saturday - AR list size of data above 1000: 0
# Saturday - AZ list size: 33051
# Saturday - AZ list size of data above 1000: 0
# Saturday - CA list size: 21597
# Saturday - CA list size of data above 1000: 0
# Saturday - CO list size: 19203
# Saturday - CO list size of data above 1000: 0
# Saturday - CT list size: 11109
# Saturday - CT list size of data above 1000: 0
# Saturday - DE list size: 32951
# Saturday - DE list size of data above 1000: 0
# Saturday - GA list size: 15839
# Saturday - GA list size of data above 1000: 0
# Saturday - ID list size: 26300
# Saturday - ID list size of data above 1000: 0
# Saturday - IL list size: 24884
# Saturday - IL list size of data above 1000: 0
# Saturday - KY list size: 13383
# Saturday - KY list size of data above 1000: 0
# Saturday - LA list size: 15848
# Saturday - LA list size of data above 1000: 0
# Saturday - MA list size: 30385
# Saturday - MA list size of data above 1000: 0
# Saturday - MD list size: 26699
# Saturday - MD list size of data above 1000: 0
# Saturday - ME list size: 33115
# Saturday - ME list size of data above 1000: 0
# Saturday - MI list size: 7614
# Saturday - MI list size of data above 1000: 0
# Saturday - MN list size: 18816
# Saturday - MN list size of data above 1000: 0
# Saturday - MS list size: 21895
# Saturday - MS list size of data above 1000: 0
# Saturday - MT list size: 22201
# Saturday - MT list size of data above 1000: 0
# Saturday - NC list size: 27368
# Saturday - NC list size of data above 1000: 0
# Saturday - ND list size: 33046
# Saturday - ND list size of data above 1000: 0
# Saturday - NE list size: 33029
# Saturday - NE list size of data above 1000: 0
# Saturday - NH list size: 23510
# Saturday - NH list size of data above 1000: 0
# Saturday - NM list size: 21202
# Saturday - NM list size of data above 1000: 0
# Saturday total: 580084
#
# whiskers:  [30.0, 396.0, 0.0, 132.0, 185.0, 794.0, 1.0, 191.0, 0.0, 108.0, 1.0, 164.0, 0.0, 218.0, 1.0, 154.0, 0.0, 106.0, 167.0, 257.0, 3.0, 286.0, 1.0, 144.0, 0.0, 119.0, 0.0, 197.0, 0.0, 335.0, 1.0, 286.0, 0.0, 434.0, 1.0, 162.0, 2.0, 215.0, 1.0, 223.0, 1.0, 101.0, 0.0, 134.0, 159.0, 244.0, 0.0, 295.0, 1.0, 139.0]
# caps:  [30.0, 396.0, 0.0, 132.0, 185.0, 794.0, 1.0, 191.0, 0.0, 108.0, 1.0, 164.0, 0.0, 218.0, 1.0, 154.0, 0.0, 106.0, 167.0, 257.0, 3.0, 286.0, 1.0, 144.0, 0.0, 119.0, 0.0, 197.0, 0.0, 335.0, 1.0, 286.0, 0.0, 434.0, 1.0, 162.0, 2.0, 215.0, 1.0, 223.0, 1.0, 101.0, 0.0, 134.0, 159.0, 244.0, 0.0, 295.0, 1.0, 139.0]
# boxes:  [151.0, 15.0, 413.0, 21.0, 11.0, 17.0, 18.0, 17.0, 11.0, 190.0, 24.0, 12.0, 14.0, 17.0, 23.0, 24.0, 59.0, 15.0, 23.0, 21.0, 11.0, 9.0, 177.0, 23.0, 12.0]
# medians:  [201.0, 32.0, 498.0, 42.0, 26.0, 49.0, 47.0, 36.0, 28.0, 199.0, 54.0, 26.0, 30.0, 44.0, 61.0, 55.0, 109.0, 34.0, 51.0, 46.0, 25.0, 23.0, 187.0, 52.0, 26.0]
# means:  [211.65662852171585, 54.776098204321805, 498.4877158717105, 73.93613282433498, 40.92438764643237, 75.28048780487805, 97.96773837145066, 68.27362670713202, 40.8293612349028, 210.22560924893952, 114.7680463168268, 47.964628600303186, 46.43707345710721, 73.86286054511775, 117.08988539711696, 103.00750196624115, 182.68069753457607, 72.60877600906218, 77.98364421574934, 92.2932932395425, 41.636188513574055, 76.42864927044863, 201.0023575518202, 132.93787575150301, 50.23537811626108]
# fliers:  []
# Sunday - AK list size: 14188
# Sunday - AK list size of data above 1000: 0
# Sunday - AL list size: 27791
# Sunday - AL list size of data above 1000: 0
# Sunday - AR list size: 18860
# Sunday - AR list size of data above 1000: 0
# Sunday - AZ list size: 31859
# Sunday - AZ list size of data above 1000: 0
# Sunday - CA list size: 21593
# Sunday - CA list size of data above 1000: 0
# Sunday - CO list size: 18400
# Sunday - CO list size of data above 1000: 0
# Sunday - CT list size: 11633
# Sunday - CT list size of data above 1000: 0
# Sunday - DE list size: 31907
# Sunday - DE list size of data above 1000: 0
# Sunday - GA list size: 16290
# Sunday - GA list size of data above 1000: 0
# Sunday - ID list size: 25775
# Sunday - ID list size of data above 1000: 0
# Sunday - IL list size: 24769
# Sunday - IL list size of data above 1000: 0
# Sunday - KY list size: 12823
# Sunday - KY list size of data above 1000: 0
# Sunday - LA list size: 16086
# Sunday - LA list size of data above 1000: 0
# Sunday - MA list size: 30236
# Sunday - MA list size of data above 1000: 0
# Sunday - MD list size: 21746
# Sunday - MD list size of data above 1000: 0
# Sunday - ME list size: 31909
# Sunday - ME list size of data above 1000: 0
# Sunday - MI list size: 7749
# Sunday - MI list size of data above 1000: 0
# Sunday - MN list size: 19310
# Sunday - MN list size of data above 1000: 0
# Sunday - MS list size: 23039
# Sunday - MS list size of data above 1000: 0
# Sunday - MT list size: 19062
# Sunday - MT list size of data above 1000: 0
# Sunday - NC list size: 25810
# Sunday - NC list size of data above 1000: 0
# Sunday - ND list size: 31734
# Sunday - ND list size of data above 1000: 0
# Sunday - NE list size: 31915
# Sunday - NE list size of data above 1000: 0
# Sunday - NH list size: 23288
# Sunday - NH list size of data above 1000: 0
# Sunday - NM list size: 21792
# Sunday - NM list size of data above 1000: 0
# Sunday total: 559564
#
# whiskers:  [0.0, 443.0, 0.0, 158.0, 61.0, 856.0, 0.0, 236.0, 0.0, 113.0, 1.0, 137.0, 1.0, 238.0, 1.0, 152.0, 1.0, 142.0, 123.0, 302.0, 1.0, 365.0, 0.0, 203.0, 1.0, 135.0, 0.0, 189.0, 0.0, 370.0, 0.0, 317.0, 9.0, 407.0, 2.0, 226.0, 1.0, 278.0, 0.0, 346.0, 0.0, 128.0, 0.0, 118.0, 150.0, 256.0, 1.0, 291.0, 0.0, 158.0]
# caps:  [0.0, 443.0, 0.0, 158.0, 61.0, 856.0, 0.0, 236.0, 0.0, 113.0, 1.0, 137.0, 1.0, 238.0, 1.0, 152.0, 1.0, 142.0, 123.0, 302.0, 1.0, 365.0, 0.0, 203.0, 1.0, 135.0, 0.0, 189.0, 0.0, 370.0, 0.0, 317.0, 9.0, 407.0, 2.0, 226.0, 1.0, 278.0, 0.0, 346.0, 0.0, 128.0, 0.0, 118.0, 150.0, 256.0, 1.0, 291.0, 0.0, 158.0]
# boxes:  [161.0, 16.0, 359.0, 19.0, 11.0, 22.0, 21.0, 17.0, 15.0, 190.0, 25.0, 28.0, 10.0, 14.0, 23.0, 22.0, 78.5, 21.0, 23.0, 34.0, 11.0, 8.0, 179.0, 21.0, 11.0]
# medians:  [219.0, 32.0, 489.0, 54.0, 28.0, 50.0, 48.0, 39.0, 35.0, 202.0, 64.0, 54.0, 27.0, 37.0, 69.0, 59.0, 132.0, 50.0, 59.0, 71.0, 23.0, 22.0, 191.0, 53.0, 30.0]
# means:  [246.14557310079346, 68.23735156531126, 477.4621220215835, 90.79169760160109, 42.79080214894405, 54.17964340112893, 113.05080581761007, 69.29206757137932, 61.74084784347505, 229.98578379521896, 108.02181944928546, 70.81407519625395, 51.31611486211665, 65.89641486969175, 122.78220390013433, 106.21480075901329, 192.0596175478065, 87.3615219314878, 105.67533553355335, 126.33293859908817, 46.367345964778316, 58.22014937131693, 203.72824690584363, 119.50050771730301, 51.66189096372612]
# fliers:  []
